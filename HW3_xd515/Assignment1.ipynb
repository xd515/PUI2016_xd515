# %%
from __future__ import print_function
import os
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import pylab as pl
# %matplotlib inline

# %% [markdown]
# ### Assignment 1

# %% [markdown]
# ##### Chi sq Distribution: df = 100, N=100

# %%
distributions = ['chisq']

# %%
mymean = 100
df = mymean
md = {}
md['chisq'] = np.random.chisquare(df, size=100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 100.60, standard deviation: 15.48

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
md['chisq'] = {}
for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ##### Binomial Distribution: df = 100, N=100

# %%
distributions = ['binomial']

# %%
mymean = 100
df = mymean
md = {}
md['binomial'] = np.random.binomial(n=200, p=0.5, size=100)
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# binomial mean: 99.22, standard deviation: 6.96

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
md['binomial'] = {}
for n in mysize:
    md['binomial'][n] = np.random.binomial(n=200, p=0.5, size = n)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('binomial', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ##### Lognormal Distribution: df = 100, N=100

# %%
distributions = ['lognormal']

# %%
mymean = 100
df = mymean
md = {}
md['lognormal'] = np.random.lognormal(df, size=100)
pl.hist(md['lognormal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("lognormal mean: %.2f, standard deviation: %.2f"%(md['lognormal'].mean(), md['lognormal'].std()))
# Out:
# lognormal mean: 46880714171729159238680904538130555173076992.00, standard deviation: 49995102304807372445298769997269412834443264.00

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
md['lognormal'] = {}
for n in mysize:
    md['lognormal'][n] = np.random.lognormal(df, size = n)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['lognormal']['means'] = {}
axlognormal_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lognormal']:
    if not type(nn) == str:
        md['lognormal']['means'][nn] = md['lognormal'][nn].mean()
        axlognormal_mu_n.plot(nn, md['lognormal']['means'][nn], 'o')
        axlognormal_mu_n.set_xlabel('sample size', fontsize=18)
        axlognormal_mu_n.set_ylabel('sample mean', fontsize=18)
        axlognormal_mu_n.set_title('lognormal', fontsize=18)
        axlognormal_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ##### Poisson Distribution: df = 100, N=100

# %%
distributions = ['poisson']

# %%
mymean = 100
df = mymean
md = {}
md['poisson'] = np.random.poisson(df, size=100)
pl.hist(md['poisson'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("poisson mean: %.2f, standard deviation: %.2f"%(md['poisson'].mean(), md['poisson'].std()))
# Out:
# poisson mean: 100.79, standard deviation: 10.92

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
md['poisson'] = {}
for n in mysize:
    md['poisson'][n] = np.random.poisson(df, size = n)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['poisson']['means'] = {}
axpoisson_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['poisson']:
    if not type(nn) == str:
        md['poisson']['means'][nn] = md['poisson'][nn].mean()
        axpoisson_mu_n.plot(nn, md['poisson']['means'][nn], 'o')
        axpoisson_mu_n.set_xlabel('sample size', fontsize=18)
        axpoisson_mu_n.set_ylabel('sample mean', fontsize=18)
        axpoisson_mu_n.set_title('poisson', fontsize=18)
        axpoisson_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ##### Normal Distribution: df = 100, N=100

# %%
distributions = ['normal']

# %%
mymean = 100
df = mymean
md = {}
md['normal'] = np.random.normal(df, size=100)
pl.hist(md['normal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("normal mean: %.2f, standard deviation: %.2f"%(md['normal'].mean(), md['normal'].std()))
# Out:
# normal mean: 100.03, standard deviation: 1.04

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
md['normal'] = {}
for n in mysize:
    md['normal'][n] = np.random.normal(df, size = n)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['normal']['means'] = {}
axnormal_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['normal']:
    if not type(nn) == str:
        md['normal']['means'][nn] = md['normal'][nn].mean()
        #and plot it
        axnormal_mu_n.plot(nn, md['normal']['means'][nn], 'o')
        axnormal_mu_n.set_xlabel('sample size', fontsize=18)
        axnormal_mu_n.set_ylabel('sample mean', fontsize=18)
        axnormal_mu_n.set_title('normal', fontsize=18)
        axnormal_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
